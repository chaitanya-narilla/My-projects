# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %pwd
# %cd '/Users/chaitanya/Downloads'
# Out:
# /Users/chaitanya/Downloads

# %%
df = pd.read_csv("train 2.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023971        0.020443            0.003825
# Occupation         -0.023971    1.000000        0.024280           -0.007618
# Marital_Status      0.020443    0.024280        1.000000            0.019888
# Product_Category_1  0.003825   -0.007618        0.019888            1.000000
# Product_Category_2  0.001529   -0.000384        0.015138            0.540583
# Product_Category_3  0.003419    0.013263        0.019473            0.229678
# Purchase            0.004716    0.020833       -0.000463           -0.343703
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                       0.001529            0.003419  0.004716
# Occupation                   -0.000384            0.013263  0.020833
# Marital_Status                0.015138            0.019473 -0.000463
# Product_Category_1            0.540583            0.229678 -0.343703
# ...

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(), center=0, cmap= 'BrBG', annot=True)

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.shape
# Out:
# (550068, 12)

# %%
df['Gender'].value_counts()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
df['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
df['Product_Category_2'].value_counts()
# Out:
# 8.0     64088
# 14.0    55108
# 2.0     49217
# 16.0    43255
# 15.0    37855
# 5.0     26235
# 4.0     25677
# 6.0     16466
# 11.0    14134
# 17.0    13320
# 13.0    10531
# 9.0      5693
# 12.0     5528
# 10.0     3043
# 3.0      2884
# 18.0     2770
# 7.0       626
# Name: Product_Category_2, dtype: int64

# %%
df['Product_Category_3'].value_counts()
# Out:
# 16.0    32636
# 15.0    28013
# 14.0    18428
# 17.0    16702
# 5.0     16658
# 8.0     12562
# 9.0     11579
# 12.0     9246
# 13.0     5459
# 6.0      4890
# 18.0     4629
# 4.0      1875
# 11.0     1805
# 10.0     1726
# 3.0       613
# Name: Product_Category_3, dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan , strategy = 'mean')
imputer = imputer.fit(df.iloc[:, 9:11].values)
df.iloc[:,9:11] = imputer.transform(df.iloc[:, 9:11].values)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float64
#  10  Product_Category_3          550068 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.drop(['User_ID'],axis=1)
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 550063  P00372445      M  51-55          13             B
# 550064  P00375436      F  26-35           1             C
# 550065  P00375436      F  26-35          15             B
# 550066  P00375436      F    55+           1             C
# 550067  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df = df.drop(['Product_ID'],axis=1)

# %%
df = df.drop(['User_ID'],axis=1)

# %%
df
# Out:
#        Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F   0-17          10             A                          2
# 1           F   0-17          10             A                          2
# 2           F   0-17          10             A                          2
# 3           F   0-17          10             A                          2
# 4           M    55+          16             C                         4+
# ...       ...    ...         ...           ...                        ...
# 550063      M  51-55          13             B                          1
# 550064      F  26-35           1             C                          3
# 550065      F  26-35          15             B                         4+
# 550066      F    55+           1             C                          2
# 550067      F  46-50           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['Gender'] = labelencoder.fit_transform(df['Gender'])
df
# Out:
#         Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0            0   0-17          10             A                          2
# 1            0   0-17          10             A                          2
# 2            0   0-17          10             A                          2
# 3            0   0-17          10             A                          2
# 4            1    55+          16             C                         4+
# ...        ...    ...         ...           ...                        ...
# 550063       1  51-55          13             B                          1
# 550064       0  26-35           1             C                          3
# 550065       0  26-35          15             B                         4+
# 550066       0    55+           1             C                          2
# 550067       0  46-50           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['Age'] = labelencoder.fit_transform(df['Age'])
df
# Out:
#         Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0            0    0          10             A                          2
# 1            0    0          10             A                          2
# 2            0    0          10             A                          2
# 3            0    0          10             A                          2
# 4            1    6          16             C                         4+
# ...        ...  ...         ...           ...                        ...
# 550063       1    5          13             B                          1
# 550064       0    2           1             C                          3
# 550065       0    2          15             B                         4+
# 550066       0    6           1             C                          2
# 550067       0    4           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df['Stay_In_Current_City_Years'].replace(['4+'],[4],inplace=True)

# %%
df
# Out:
#         Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0            0    0          10             A                          2
# 1            0    0          10             A                          2
# 2            0    0          10             A                          2
# 3            0    0          10             A                          2
# 4            1    6          16             C                          4
# ...        ...  ...         ...           ...                        ...
# 550063       1    5          13             B                          1
# 550064       0    2           1             C                          3
# 550065       0    2          15             B                          4
# 550066       0    6           1             C                          2
# 550067       0    4           0             B                          4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['City_Category'] = labelencoder.fit_transform(df['City_Category'])
df
# Out:
#         Gender  Age  Occupation  City_Category Stay_In_Current_City_Years  \
# 0            0    0          10              0                          2
# 1            0    0          10              0                          2
# 2            0    0          10              0                          2
# 3            0    0          10              0                          2
# 4            1    6          16              2                          4
# ...        ...  ...         ...            ...                        ...
# 550063       1    5          13              1                          1
# 550064       0    2           1              2                          3
# 550065       0    2          15              1                          4
# 550066       0    6           1              2                          2
# 550067       0    4           0              1                          4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
X = df.iloc[:, 0:9].values
y = df.iloc[:, 9].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score,mean_squared_error

DTR = DecisionTreeRegressor(random_state = 0,criterion='mse')
DTR.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
y_pred = DTR.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# 3320.3003593108665

# %%
print("Accuracy on test set: {:.5f}".format(DTR.score(X_test, y_test)))
# Out:
# Accuracy on test set: 0.56343

# %%
from sklearn.linear_model import LinearRegression
f=LinearRegression()
f.fit(X_train,y_train)
f.score(X_test,y_test)
# Out:
# 0.12824198819373567

# %%
from sklearn.ensemble import RandomForestRegressor
n=RandomForestRegressor(random_state = 0, bootstrap= True, )
n.fit(X_train,y_train)
n.score(X_test,y_test)
# Out:
# 0.6327909760086632

# %%
y_pred = n.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# 3045.124245765217

# %%
df_t = pd.read_csv("test 2.csv")

# %%
df_t
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df_t = df_t.drop(['User_ID'],axis=1)

# %%
df_t = df_t.drop(['Product_ID'],axis=1)

# %%
df_t
# Out:
#        Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0           M  46-50           7             B                          2
# 1           M  26-35          17             C                          0
# 2           F  36-45           1             B                         4+
# 3           F  36-45           1             B                         4+
# 4           F  26-35           1             C                          1
# ...       ...    ...         ...           ...                        ...
# 233594      F  26-35          15             B                         4+
# 233595      F  26-35          15             B                         4+
# 233596      F  26-35          15             B                         4+
# 233597      F  46-50           1             C                         4+
# 233598      F  46-50           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan , strategy = 'mean')
imputer = imputer.fit(df_t.iloc[:, 7:9].values)
df_t.iloc[:,7:9] = imputer.transform(df_t.iloc[:, 7:9].values)
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      233599 non-null  object
#  1   Age                         233599 non-null  object
#  2   Occupation                  233599 non-null  int64
#  3   City_Category               233599 non-null  object
#  4   Stay_In_Current_City_Years  233599 non-null  object
#  5   Marital_Status              233599 non-null  int64
#  6   Product_Category_1          233599 non-null  int64
#  7   Product_Category_2          233599 non-null  float64
#  8   Product_Category_3          233599 non-null  float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 16.0+ MB

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df_t['Gender'] = labelencoder.fit_transform(df_t['Gender'])
df_t['Age'] = labelencoder.fit_transform(df_t['Age'])
df_t['Stay_In_Current_City_Years'].replace(['4+'],[4],inplace=True)
df_t['City_Category'] = labelencoder.fit_transform(df_t['City_Category'])

# %%
df_t
# Out:
#         Gender  Age  Occupation  City_Category Stay_In_Current_City_Years  \
# 0            1    4           7              1                          2
# 1            1    2          17              2                          0
# 2            0    3           1              1                          4
# 3            0    3           1              1                          4
# 4            0    2           1              2                          1
# ...        ...  ...         ...            ...                        ...
# 233594       0    2          15              1                          4
# 233595       0    2          15              1                          4
# 233596       0    2          15              1                          4
# 233597       0    4           1              2                          4
# 233598       0    4           0              1                          4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
y_pred_test = n.predict(df_t)

# %%
y_pred_test
# Out:
# array([17666.03666667, 19103.14      ,   327.71833333, ...,
#        15950.14666667,   254.74657143,   353.39      ])

# %%
df_t_2 = pd.read_csv("test 2.csv")

# %%
df_ot = df_t_2.iloc[:, 7:9].values

# %%
df_prod
# Out:
# 0         P00128942
# 1         P00113442
# 2         P00288442
# 3         P00145342
# 4         P00053842
#             ...
# 233594    P00118942
# 233595    P00254642
# 233596    P00031842
# 233597    P00124742
# 233598    P00316642
# Name: Product_ID, Length: 233599, dtype: object

# %%
df_t_2["Purchase"]=y_out

# %%
df_t_2
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df_out = df_t_2["User_ID"]

# %%
df_out=pd.DataFrame(df_out)

# %%
df_out["Product_ID"] = df_t_2["Product_ID"]

# %%
df_out["Purchase"]=df_t_2["Purchase"]

# %%
df_out
# Out:
#         User_ID Product_ID      Purchase
# 0       1000004  P00128942  17666.036667
# 1       1000009  P00113442  19103.140000
# 2       1000010  P00288442    327.718333
# 3       1000010  P00145342    327.718333
# 4       1000011  P00053842    410.591000
# ...         ...        ...           ...
# 233594  1006036  P00118942    183.552000
# 233595  1006036  P00254642    183.552000
# 233596  1006036  P00031842  15950.146667
# 233597  1006037  P00124742    254.746571
# 233598  1006039  P00316642    353.390000
#
# [233599 rows x 3 columns]

# %%
y_out = pd.DataFrame(y_pred_test)

# %%
y_out
# Out:
#                    0
# 0       17666.036667
# 1       19103.140000
# 2         327.718333
# 3         327.718333
# 4         410.591000
# ...              ...
# 233594    183.552000
# 233595    183.552000
# 233596  15950.146667
# 233597    254.746571
# 233598    353.390000
#
# [233599 rows x 1 columns]

# %%
df_out.to_csv('submission_1.csv', index=False)
